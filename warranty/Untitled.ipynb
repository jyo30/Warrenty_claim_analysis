# %%
import numpy as np
import pandas as pd
import codecs

# %%
df=pd.read_excel("ST-GWC Debit ID 6001363_(DISPUTED CLAIMS) 05122023.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 694 entries, 0 to 693
# Data columns (total 42 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Model Year                                         693 non-null    float64
#  1   Labor Hours                                        693 non-null    float64
#  2   Labor hours adjusted to .4 per sensor              694 non-null    float64
#  3   Material Cost adjusted to 64.47 per sensor         694 non-null    float64
#  4   Part MarkUp Adjusted to 18.42 per sensor           694 non-null    float64
#  5   Misc. Amt (total)                                  694 non-null    float64
#  6   Custom Column                                      693 non-null    float64
#  7   Customer Paid Amount                               693 non-null    float64
# ...

# %%
df.head()
# Out:
#    Model Year  Labor Hours  Labor hours adjusted to .4 per sensor  \
# 0      2020.0          0.6                                  70.94
# 1      2021.0         14.2                                  35.47
# 2      2022.0         18.6                                  35.47
# 3      2021.0         14.6                                  35.47
# 4      2022.0          1.2                                 141.88
#
#    Material Cost adjusted to 64.47 per sensor  \
# 0                                      128.94
# 1                                       64.47
# 2                                       64.47
# 3                                       64.47
# 4                                      257.88
#
#    Part MarkUp Adjusted to 18.42 per sensor  Misc. Amt (total)  Custom Column  \
# 0                                     36.84           0.000000            0.0
# 1                                     18.42           0.000000            0.0
# ...
